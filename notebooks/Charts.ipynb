# %%
import pandas as pd
from datetime import datetime

# %%
charts = pd.read_csv('../data/charts.csv')

# %%
charts = charts.drop_duplicates(subset=['song','artist'])

# %%
charts['date'] = pd.to_datetime(charts['date'])

# %%
charts['release_year'] = charts.date.dt.year

# %%
charts.head(1)
# Out:
#         date  rank        song artist  last-week  peak-rank  weeks-on-board  \
# 0 2021-11-06     1  Easy On Me  Adele        1.0          1               3
#
#    release_year
# 0          2021

# %%
charts.dtypes
# Out:
# date              datetime64[ns]
# rank                       int64
# song                      object
# artist                    object
# last-week                float64
# peak-rank                  int64
# weeks-on-board             int64
# release_year               int32
# dtype: object

# %%
hit_songs = charts.loc[(charts['peak-rank'] >= 1) & (charts['peak-rank'] <= 10)]

# %%
hit_songs
# Out:
#              date  rank               song  \
# 0      2021-11-06     1         Easy On Me
# 1      2021-11-06     2               Stay
# 2      2021-11-06     3      Industry Baby
# 3      2021-11-06     4         Fancy Like
# 4      2021-11-06     5         Bad Habits
# ...           ...   ...                ...
# 329272 1958-09-29    86               When
# 329338 1958-09-22    52      Rebel-'rouser
# 329358 1958-09-22    72      Splish Splash
# 329380 1958-09-22    94  Hard Headed Woman
# 329476 1958-09-15    90         Yakety Yak
#
#                                              artist  last-week  peak-rank  \
# 0                                             Adele        1.0          1
# 1                     The Kid LAROI & Justin Bieber        2.0          1
# 2                           Lil Nas X & Jack Harlow        3.0          1
# 3                                      Walker Hayes        4.0          3
# ...

# %%
hit_count = hit_songs.artist.value_counts().to_frame().reset_index()

# %%
hit_count.dtypes
# Out:
# artist    object
# count      int64
# dtype: object

# %%
hit_count.loc[(hit_count['count'] == 1)]
# Out:
#                                            artist  count
# 753                                David Naughton      1
# 754                         Tony Camillo's Bazuka      1
# 755                                   C.W. McCall      1
# 756             Donna Summer With Brooklyn Dreams      1
# 757                                     The Clash      1
# ...                                           ...    ...
# 2482                             Voices Of Theory      1
# 2483              Puff Daddy Featuring Jimmy Page      1
# 2484                    Mase Featuring Puff Daddy      1
# 2485                                  Tatyana Ali      1
# 2486  Duane Eddy His Twangy Guitar And The Rebels      1
#
# [1734 rows x 2 columns]

# %%
hit_songs = pd.merge(hit_songs, hit_count, on='artist', how='inner')

# %%
hit_songs['date'] = hit_songs.release_year.astype(int)

# %%
 hit_songs = hit_songs[~hit_songs['artist'].str.contains('/|&|Featuring|ft')].reset_index()

# %%
hits_80s = hit_songs.loc[(hit_songs['count'] == 1) & (hit_songs['date'] >= 1980)&(hit_songs['date'] <= 1989)]

# %%
hits_90s = hit_songs.loc[(hit_songs['count'] == 1) & (hit_songs['date'] >= 1990)&(hit_songs['date'] <= 1999)]

# %%
hits_2000to2010 = hit_songs.loc[(hit_songs['count'] == 1) & (hit_songs['date'] >= 2000)&(hit_songs['date'] <= 2019)]

# %%
hits_2000to2010
# Out:
#       index  date  rank                              song  \
# 274     365  2019    42                  Sweet But Psycho
# 277     374  2019    50                          Thotiana
# 278     377  2019    50                        Youngblood
# 279     381  2019    47                          Mo Bamba
# 283     390  2018    50                          Boo'd Up
# ...     ...   ...   ...                               ...
# 1037   1498  2000    45                  U Know What's Up
# 1038   1499  2000    54          I Wanna Love You Forever
# 1052   1514  2000    39                 Steal My Sunshine
# 1053   1515  2000    42  Mambo No. 5 (A Little Bit Of...)
# 1056   1518  2000    97               We Can't Be Friends
#
#                      artist  last-week  peak-rank  weeks-on-board  \
# 274                 Ava Max       34.0         10              35
# 277                Blueface       50.0          8              20
# 278     5 Seconds Of Summer       50.0          7              48
# ...

# %%
hits_80s.to_csv('../data/80s_charts.csv')

# %%
hits_90s.to_csv('../data/90s_charts.csv')

# %%
hits_2000to2010.to_csv('../data/2000s_2010s_charts.csv')
